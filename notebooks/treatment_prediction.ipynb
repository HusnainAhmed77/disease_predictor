# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.3.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.22.4 in /opt/anaconda3/envs/mednlp/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/mednlp/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/mednlp/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.0-cp310-cp310-macosx_10_9_x86_64.whl (11.5 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# Successfully installed pandas-2.3.0 pytz-2025.2 tzdata-2025.2

# %%
import pandas as pd
from collections import defaultdict

# File path
file_path = "treatments.txt"

# Initialize
treatment_map = defaultdict(dict)
current_disease = None

# Parse the structured .txt file
with open(file_path, "r") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        if line.endswith(":") and "Medicines" not in line:
            current_disease = line[:-1]
        elif current_disease:
            if line.startswith("Medicines:"):
                treatment_map[current_disease]["medicines"] = line.replace("Medicines:", "").strip()
            elif line.startswith("Steps:"):
                treatment_map[current_disease]["steps"] = line.replace("Steps:", "").strip()
            elif line.startswith("Duration:"):
                treatment_map[current_disease]["duration"] = line.replace("Duration:", "").strip()

# Convert to DataFrame (optional)
df_treatments = pd.DataFrame.from_dict(treatment_map, orient="index")
df_treatments.reset_index(inplace=True)
df_treatments.rename(columns={"index": "Disease"}, inplace=True)

# Preview
df_treatments.head()
# Out:
#         Disease                                          medicines  \
# 0       Malaria  artemisinin-based combination therapy (ACT), i...
# 1      Diabetes                                 Metformin, insulin
# 2  Hypertension                               Lisinopril, Atenolol
# 3  Tuberculosis    isoniazid, rifampicin, pyrazinamide, ethambutol
# 4      Migraine                Sumatriptan, ibuprofen, propranolol
#
#                                                steps  \
# 0  Take ACT twice daily for 3 days. In severe cas...
# 1  Adopt a balanced diet and exercise regularly. ...
# 2  Reduce sodium intake. Manage stress and exerci...
# 3  2-month intensive phase with 4 drugs, followed...
# 4  Avoid triggers. Take NSAIDs or triptans during...
#
#                               duration
# 0                            7–10 days
# 1  Long-term; improvement in 2–4 weeks
# 2          4–6 weeks for stabilization
# 3                           6–8 months
# 4                 1–2 days per episode
